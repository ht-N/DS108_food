# %%
import pandas as pd
import re
import numpy as np

# %%
csv_file_path = "job_details_all.csv"
df = pd.read_csv(csv_file_path)
df
# Out:
#                                              Job Title  \
# 0    Kế Toán Trưởng / Chief Accountant Mảng Xây Dựn...
# 1                   Chuyên Viên Nghiệp Vụ Kế Toán Thuế
# 2    Kế Toán Tổng Hợp - Kế Toán Thuế Từ 3 Năm Kinh ...
# 3    Kế Toán Kho (Lương 9 Đến 12 Triệu) Tại Hà Nội,...
# 4    Kế Toán Nội Bộ Lương Từ 10 Đến 12 Triệu Đồng -...
# ..                                                 ...
# 382  Nhân Viên Content Marketing Thu Nhập 10-15 Tri...
# 383     Performance Marketing Team Lead (Up-To $7.000)
# 384  Video Creator/ Nhân Viên Sáng Tạo Video Tối Th...
# 385  Senior Digital Marketing – Facebook & Google A...
# 386  Thực Tập Sinh Marketing (Thu Nhập Từ 4 Triệu -...
#
#                                           Company Name                Field  \
# 0    CÔNG TY TNHH XUẤT NHẬP KHẨU VÀ ĐẦU TƯ CHỢ GỖ T...             Xây dựng
# 1    CÔNG TY TNHH DỊCH VỤ KẾ TOÁN - TƯ VẤN THUẾ THÀ...  Kế toán / Kiểm toán
# 2    CÔNG TY CỔ PHẦN PHÁT TRIỂN CÔNG NGHỆ CATECH VI...                 Khác
# 3           CÔNG TY TNHH SẢN XUẤT KEO DÁN THUẬN NGUYÊN             Sản xuất
# 4           Công ty cổ phần Vật liệu Xây dựng Huy Hùng             Xây dựng
# ..                                                 ...                  ...
# 382                   CÔNG TY TNHH SƠN BARTON VIỆT NAM             Sản xuất
# 383                                           Crossian   Thương mại điện tử
# 384             CÔNG TY CỔ PHẦN QUẢN LÝ TÀI SẢN DAPANO         Bất động sản
# 385                                 CÔNG TY TNHH NUGYM                 Khác
# 386            CÔNG TY TNHH THƯƠNG MẠI VÀ DỊCH VỤ NINA               Tư vấn
#
#         Experience          Location        Company Size         Salary  \
# 0       Trên 5 năm         Hải Phòng  500-1000 nhân viên   Tới 25 triệu
# 1            3 năm       Hồ Chí Minh     25-99 nhân viên  12 - 15 triệu
# 2            3 năm            Hà Nội       1-9 nhân viên  12 - 16 triệu
# 3            2 năm  Hà Nội, Hưng Yên     25-99 nhân viên   9 - 12 triệu
# 4            1 năm            Hà Nam   100-499 nhân viên  10 - 12 triệu
# ..             ...               ...                 ...            ...
# 382          1 năm            Hà Nội     25-99 nhân viên  10 - 15 triệu
# 383          3 năm       Hồ Chí Minh   100-499 nhân viên  Tới 7,000 USD
# 384          1 năm            Hà Nội     25-99 nhân viên  12 - 15 triệu
# 385          2 năm       Hồ Chí Minh     25-99 nhân viên  12 - 18 triệu
# 386  Không yêu cầu       Hồ Chí Minh     1000+ nhân viên     Từ 4 triệu
#
#                                        Job Description  \
# 0    Quản lý, tổ chức và giám sát toàn bộ hoạt động...
# 1    • Trao đổi khách hàng để triển khai hợp đồng k...
# 2    - Thực hiện nghiệp vụ của kế toán thuế : Báo c...
# 3    Duy trì và cập nhật hồ sơ tồn kho chính xác (n...
# 4    - Theo dõi thu chi tiền mặt: theo dõi thu chi ...
# ..                                                 ...
# 382  Xây dựng kế hoạch, định hướng nội dung của Web...
# 383  ABOUT THE ROLE\nCrossian is a high-growth tech...
# 384  MỤC TIÊU CÔNG VIỆC\n- Phát triển kênh video ma...
# 385  - Lập kế hoạch và triển khai các chiến dịch di...
# 386  - Tư vấn, hỗ trợ khách hàng về:\n+ Thiết kế We...
#
#                                       Job Requirements  \
# 0    Tốt nghiệp đại học chính quy chuyên ngành kế t...
# 1    • Có từ 3 năm kinh nghiệm vị trí Kế toán thuế ...
# 2    1. Tốt nghiệp Đại học Chuyên ngành Kế toán.\n2...
# 3    Tốt nghiệp đại học chuyên ngành Kế toán, Tài c...
# 4    - Nam/nữ trình độ đại học chuyên ngành Kế toán...
# ..                                                 ...
# 382  Giới tính: Nam ( 20 - 35t)\nTốt nghiệp từ Trun...
# 383  WHAT WE ARE LOOKING FOR\n1. A bachelor's degre...
# 384  - Trình độ: Tốt nghiệp Cao đẳng/Đại học chuyên...
# 385  - Tốt nghiệp Cao đẳng/Đại học chuyên ngành về ...
# 386  - Không yêu cầu kinh nghiệm – sẽ được đào tạo\...
#
#                                       Company Logo URL  \
# 0    https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 1    https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 2    https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 3    https://www.topcv.vn/v4/image/normal-company/l...
# 4    https://cdn-new.topcv.vn/unsafe/80x/https://st...
# ..                                                 ...
# 382  https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 383  https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 384  https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 385  https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 386  https://cdn-new.topcv.vn/unsafe/80x/https://st...
#
#                                                    URL
# 0    https://www.topcv.vn/viec-lam/ke-toan-truong-c...
# 1    https://www.topcv.vn/viec-lam/chuyen-vien-nghi...
# 2    https://www.topcv.vn/viec-lam/ke-toan-tong-hop...
# 3    https://www.topcv.vn/viec-lam/ke-toan-kho-luon...
# 4    https://www.topcv.vn/viec-lam/ke-toan-noi-bo-l...
# ..                                                 ...
# 382  https://www.topcv.vn/viec-lam/nhan-vien-conten...
# 383  https://www.topcv.vn/viec-lam/performance-mark...
# 384  https://www.topcv.vn/viec-lam/video-creator-nh...
# 385  https://www.topcv.vn/viec-lam/senior-digital-m...
# 386  https://www.topcv.vn/viec-lam/thuc-tap-sinh-ma...
#
# [387 rows x 11 columns]

# %%
df = df.dropna()

# %%
def process_experience(exp):
    if pd.isna(exp):
        return 0
    
    # Convert "2 năm" -> 2
    if "năm" in str(exp):
        match = re.search(r'(\d+)', str(exp))
        if match:
            return int(match.group(1))
    
    # Handle "Dưới 1 năm" -> 1
    if "Dưới 1 năm" in str(exp):
        return 1
    
    # Handle "không yêu cầu" or "Không yêu cầu" -> 0
    if "không yêu cầu" in str(exp).lower() or "không" in str(exp).lower():
        return 0
    
    return 0  # Default case

df['Experience_year'] = df['Experience'].apply(process_experience)
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_3548\2388425961.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Experience_year'] = df['Experience'].apply(process_experience)

# %%
def process_salary(salary):
    if pd.isna(salary):
        return {"min": "TBD", "max": "TBD"}
    
    salary = str(salary)
    
    # Case: "x - y triệu"
    if " - " in salary and "triệu" in salary:
        parts = salary.split(" - ")
        min_salary = float(parts[0].strip())
        max_salary = float(parts[1].split(" ")[0].strip())
        return {"min": min_salary, "max": max_salary}
    
    # Case: "Thỏa thuận" or "Thoả thuận"
    if "thoả thuận" in salary.lower() or "thoa thuan" in salary.lower():
        return {"min": "TBD", "max": "TBD"}
    
    # Case: "Tới z triệu"
    if "tới" in salary.lower() and "triệu" in salary.lower():
        match = re.search(r'(\d+)', salary)
        if match:
            z = float(match.group(1))
            return {"min": z/2, "max": z}
    
    # Case: "Từ z triệu"
    if "từ" in salary.lower() and "triệu" in salary.lower():
        match = re.search(r'(\d+)', salary)
        if match:
            z = float(match.group(1))
            return {"min": z, "max": z*1.5}  # Assuming max is 1.5x of min
    
    return {"min": "TBD", "max": "TBD"}  # Default case

# %%
df['minSalary'] = df['Salary'].apply(lambda x: process_salary(x)["min"])
df['maxSalary'] = df['Salary'].apply(lambda x: process_salary(x)["max"])
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_3548\3597528151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['minSalary'] = df['Salary'].apply(lambda x: process_salary(x)["min"])
# C:\Users\hello\AppData\Local\Temp\ipykernel_3548\3597528151.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['maxSalary'] = df['Salary'].apply(lambda x: process_salary(x)["max"])

# %%
def clean_job_requirements(text):
    if pd.isna(text):
        return ""
    
    # Replace bullet points, special characters and new lines with space
    cleaned_text = re.sub(r'[●•\-\*\n\r\t]', ' ', str(text))
    
    # Remove extra spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

# Create temporary cleaned column
df['Job_Requirements_Cleaned'] = df['Job Requirements'].apply(clean_job_requirements)

# Rename the cleaned column and drop the original
df['Job Requirements'] = df['Job_Requirements_Cleaned']
df = df.drop(columns=['Job_Requirements_Cleaned'])
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_3548\406067780.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Job_Requirements_Cleaned'] = df['Job Requirements'].apply(clean_job_requirements)
# C:\Users\hello\AppData\Local\Temp\ipykernel_3548\406067780.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Job Requirements'] = df['Job_Requirements_Cleaned']

# %%
df
# Out:
#                                              Job Title  \
# 0    Kế Toán Trưởng / Chief Accountant Mảng Xây Dựn...
# 1                   Chuyên Viên Nghiệp Vụ Kế Toán Thuế
# 2    Kế Toán Tổng Hợp - Kế Toán Thuế Từ 3 Năm Kinh ...
# 3    Kế Toán Kho (Lương 9 Đến 12 Triệu) Tại Hà Nội,...
# 4    Kế Toán Nội Bộ Lương Từ 10 Đến 12 Triệu Đồng -...
# ..                                                 ...
# 382  Nhân Viên Content Marketing Thu Nhập 10-15 Tri...
# 383     Performance Marketing Team Lead (Up-To $7.000)
# 384  Video Creator/ Nhân Viên Sáng Tạo Video Tối Th...
# 385  Senior Digital Marketing – Facebook & Google A...
# 386  Thực Tập Sinh Marketing (Thu Nhập Từ 4 Triệu -...
#
#                                           Company Name                Field  \
# 0    CÔNG TY TNHH XUẤT NHẬP KHẨU VÀ ĐẦU TƯ CHỢ GỖ T...             Xây dựng
# 1    CÔNG TY TNHH DỊCH VỤ KẾ TOÁN - TƯ VẤN THUẾ THÀ...  Kế toán / Kiểm toán
# 2    CÔNG TY CỔ PHẦN PHÁT TRIỂN CÔNG NGHỆ CATECH VI...                 Khác
# 3           CÔNG TY TNHH SẢN XUẤT KEO DÁN THUẬN NGUYÊN             Sản xuất
# 4           Công ty cổ phần Vật liệu Xây dựng Huy Hùng             Xây dựng
# ..                                                 ...                  ...
# 382                   CÔNG TY TNHH SƠN BARTON VIỆT NAM             Sản xuất
# 383                                           Crossian   Thương mại điện tử
# 384             CÔNG TY CỔ PHẦN QUẢN LÝ TÀI SẢN DAPANO         Bất động sản
# 385                                 CÔNG TY TNHH NUGYM                 Khác
# 386            CÔNG TY TNHH THƯƠNG MẠI VÀ DỊCH VỤ NINA               Tư vấn
#
#         Experience          Location        Company Size         Salary  \
# 0       Trên 5 năm         Hải Phòng  500-1000 nhân viên   Tới 25 triệu
# 1            3 năm       Hồ Chí Minh     25-99 nhân viên  12 - 15 triệu
# 2            3 năm            Hà Nội       1-9 nhân viên  12 - 16 triệu
# 3            2 năm  Hà Nội, Hưng Yên     25-99 nhân viên   9 - 12 triệu
# 4            1 năm            Hà Nam   100-499 nhân viên  10 - 12 triệu
# ..             ...               ...                 ...            ...
# 382          1 năm            Hà Nội     25-99 nhân viên  10 - 15 triệu
# 383          3 năm       Hồ Chí Minh   100-499 nhân viên  Tới 7,000 USD
# 384          1 năm            Hà Nội     25-99 nhân viên  12 - 15 triệu
# 385          2 năm       Hồ Chí Minh     25-99 nhân viên  12 - 18 triệu
# 386  Không yêu cầu       Hồ Chí Minh     1000+ nhân viên     Từ 4 triệu
#
#                                        Job Description  \
# 0    Quản lý, tổ chức và giám sát toàn bộ hoạt động...
# 1    • Trao đổi khách hàng để triển khai hợp đồng k...
# 2    - Thực hiện nghiệp vụ của kế toán thuế : Báo c...
# 3    Duy trì và cập nhật hồ sơ tồn kho chính xác (n...
# 4    - Theo dõi thu chi tiền mặt: theo dõi thu chi ...
# ..                                                 ...
# 382  Xây dựng kế hoạch, định hướng nội dung của Web...
# 383  ABOUT THE ROLE\nCrossian is a high-growth tech...
# 384  MỤC TIÊU CÔNG VIỆC\n- Phát triển kênh video ma...
# 385  - Lập kế hoạch và triển khai các chiến dịch di...
# 386  - Tư vấn, hỗ trợ khách hàng về:\n+ Thiết kế We...
#
#                                       Job Requirements  \
# 0    Tốt nghiệp đại học chính quy chuyên ngành kế t...
# 1    Có từ 3 năm kinh nghiệm vị trí Kế toán thuế từ...
# 2    1. Tốt nghiệp Đại học Chuyên ngành Kế toán. 2....
# 3    Tốt nghiệp đại học chuyên ngành Kế toán, Tài c...
# 4    Nam/nữ trình độ đại học chuyên ngành Kế toán/ ...
# ..                                                 ...
# 382  Giới tính: Nam ( 20 35t) Tốt nghiệp từ Trung C...
# 383  WHAT WE ARE LOOKING FOR 1. A bachelor's degree...
# 384  Trình độ: Tốt nghiệp Cao đẳng/Đại học chuyên n...
# 385  Tốt nghiệp Cao đẳng/Đại học chuyên ngành về Ma...
# 386  Không yêu cầu kinh nghiệm – sẽ được đào tạo Si...
#
#                                       Company Logo URL  \
# 0    https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 1    https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 2    https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 3    https://www.topcv.vn/v4/image/normal-company/l...
# 4    https://cdn-new.topcv.vn/unsafe/80x/https://st...
# ..                                                 ...
# 382  https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 383  https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 384  https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 385  https://cdn-new.topcv.vn/unsafe/80x/https://st...
# 386  https://cdn-new.topcv.vn/unsafe/80x/https://st...
#
#                                                    URL  Experience_year  \
# 0    https://www.topcv.vn/viec-lam/ke-toan-truong-c...                5
# 1    https://www.topcv.vn/viec-lam/chuyen-vien-nghi...                3
# 2    https://www.topcv.vn/viec-lam/ke-toan-tong-hop...                3
# 3    https://www.topcv.vn/viec-lam/ke-toan-kho-luon...                2
# 4    https://www.topcv.vn/viec-lam/ke-toan-noi-bo-l...                1
# ..                                                 ...              ...
# 382  https://www.topcv.vn/viec-lam/nhan-vien-conten...                1
# 383  https://www.topcv.vn/viec-lam/performance-mark...                3
# 384  https://www.topcv.vn/viec-lam/video-creator-nh...                1
# 385  https://www.topcv.vn/viec-lam/senior-digital-m...                2
# 386  https://www.topcv.vn/viec-lam/thuc-tap-sinh-ma...                0
#
#     minSalary maxSalary
# 0        12.5      25.0
# 1        12.0      15.0
# 2        12.0      16.0
# 3         9.0      12.0
# 4        10.0      12.0
# ..        ...       ...
# 382      10.0      15.0
# 383       TBD       TBD
# 384      12.0      15.0
# 385      12.0      18.0
# 386       4.0       6.0
#
# [362 rows x 14 columns]

# %%
df.to_csv(fr"job_details_all_processed.csv", index=False)
